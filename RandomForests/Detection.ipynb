# %% [markdown]
# # Spam detection using random forests algorithm

# %% [markdown]
# **importing all necessary modules**

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,roc_curve,auc,recall_score,precision_score,f1_score,confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# **importing the dataset and basic cleaning and analysis**

# %%
data= pd.read_csv('spam_detection_dataset.csv')
df= pd.DataFrame(data)

df.head(10)
# Out:
#    num_links  num_words  has_offer  sender_score  all_caps  is_spam
# 0          3         98          1      0.718607         0        0
# 1          0        170          0      0.698901         1        0
# 2          0         38          0      0.620466         0        0
# 3          0        116          0      0.701755         0        0
# 4          3         89          1      0.583621         1        1
# 5          2        197          0      0.466201         0        0
# 6          0        166          1      1.000000         0        0
# 7          0        113          0      0.600813         0        0
# 8          1        169          0      0.753108         0        0
# 9          1        150          1      1.000000         0        0

# %% [markdown]
# **checking for missing values and duplicated rows**

# %%
print(df.isna().sum())
df.duplicated().sum()
# Out:
# num_links       0
# num_words       0
# has_offer       0
# sender_score    0
# all_caps        0
# is_spam         0
# dtype: int64
# np.int64(402)

# %% [markdown]
# **checking for datatypes to detect any irregularity**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num_links     20000 non-null  int64
#  1   num_words     20000 non-null  int64
#  2   has_offer     20000 non-null  int64
#  3   sender_score  20000 non-null  float64
#  4   all_caps      20000 non-null  int64
#  5   is_spam       20000 non-null  int64
# dtypes: float64(1), int64(5)
# memory usage: 937.6 KB

# %% [markdown]
# **predicition using Randomforests model**

# %%
x= df[['num_links','num_words','has_offer','sender_score','all_caps']]
y=df['is_spam']

X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.2, random_state=42)

rf= RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None)

rf.fit(X_train,y_train)

y_pred= rf.predict(X_test)
y_prob= rf.predict_proba(X_test)[:,1]

threshold=0.4

y_pred_new= (y_prob > threshold).astype(int)

acc= accuracy_score(y_test,y_pred_new)
confusion= confusion_matrix(y_test,y_pred_new)
print(acc)
print(confusion)
# Out:
# 0.95375
# [[3530  101]
#  [  84  285]]
